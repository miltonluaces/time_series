# %% [markdown]
# # Basic transforms

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
from random import randrange
from time_series.transforms.basic_transforms import *

# %%
ts = np.array([i+randrange(10) for i in range(1,100)])
plt.plot(ts);

# %%
ts_log = np.log(ts)
ts_sqrt = np.sqrt(ts)
ts_cubic = np.power(ts,3)
plt.title('Log')
plt.plot(ts_log);
plt.show()
plt.title('Sqrt')
plt.plot(ts_sqrt);
plt.show()
plt.title('Cubic')
plt.plot(ts_cubic);
