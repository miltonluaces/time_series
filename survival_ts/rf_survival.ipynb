# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %pylab inline
figsize(12,6)
from random_survival_forest import RandomSurvivalForest
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('D:/data/csv/telco_customer-churn_cleansed.csv') 
df.head()
# Out:
#    Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0           0  7590-VHVEG  Female              0     Yes         No       1
# 1           1  5575-GNVDE    Male              0      No         No      34
# 2           2  3668-QPYBK    Male              0      No         No       2
# 3           3  7795-CFOCW    Male              0      No         No      45
# 4           4  9237-HQITU  Female              0      No         No       2
#
#   PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0           No  No phone service             DSL  ...               No
# 1          Yes                No             DSL  ...              Yes
# 2          Yes                No             DSL  ...               No
# 3           No  No phone service             DSL  ...              Yes
# 4          Yes                No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df_r= df.loc[:,['tenure','Churn','gender','Partner','Dependents','PhoneService','MonthlyCharges','SeniorCitizen','StreamingTV']]
df_dummy = pd.get_dummies(df_r.head(9), drop_first=True)
df_dummy
# Out:
#    tenure  Churn  MonthlyCharges  SeniorCitizen  gender_Male  Partner_Yes  \
# 0       1      0           29.85              0            0            1
# 1      34      0           56.95              0            1            0
# 2       2      1           53.85              0            1            0
# 3      45      0           42.30              0            1            0
# 4       2      1           70.70              0            0            0
# 5       8      1           99.65              0            0            0
# 6      22      0           89.10              0            1            0
# 7      10      0           29.75              0            0            0
# 8      28      1          104.80              0            0            1
#
#    Dependents_Yes  PhoneService_Yes  StreamingTV_Yes
# 0               0                 0                0
# 1               0                 1                0
# 2               0                 1                0
# ...

# %%
y = df_dummy['Churn']
df_dummy.drop('Churn', axis=1)
y
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# Name: Churn, dtype: int64

# %%
X= df_dummy
timeline = range(0, 8, 1)
rsf = RandomSurvivalForest(n_estimators=3, timeline=timeline)
rsf.fit(X, y)
#round(rsf.oob_score, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-5cabff222e09> in <module>
#       2 timeline = range(0, 8, 1)
#       3 rsf = RandomSurvivalForest(n_estimators=3, timeline=timeline)
# ----> 4 rsf.fit(X, y)
#       5 #round(rsf.oob_score, 3)
#
# C:\Program Files\Python38\lib\site-packages\random_survival_forest\RandomSurvivalForest.py in fit(self, x, y)
#      48         elif self.n_jobs is None:
#      49             self.n_jobs = 1
# ---> 50         self.random_states = np.random.RandomState(seed=self.random_state).randint(0, 2**32-1, self.n_estimators)
#      51         self.bootstrap_idxs = self.draw_bootstrap_samples(x)
#      52
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int32()
#
# ValueError: high is out of bounds for int32

# %%
y_pred = rsf.predict(X_val)
c_val = concordance_index(y_val["time"], y_pred, y_val["event"])
round(c_val, 3)
