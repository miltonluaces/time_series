# %% [markdown]
# # Basic forecasting methods

# %%
import sys
sys.path.append('D:/source/repos')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels
from ds_topics.utils.basic_methods import *

# %%
df = pd.read_csv('D:/data/csv/energy.csv', nrows=150)
ts = df['value']
ts.index = df['date']
plt.figure(figsize=(20, 10))
plt.plot(hist, color='darkslateblue', linewidth=2);

# %%
fcst = Naive(ts=ts, hor=30)
PlotFcst(ts,fcst)

# %%
fcst = SimpleAvg(ts=ts, hor=30)
PlotFcst(ts,fcst)

# %%
fcst = MovingAvg(ts=ts, hor=30, mw=6)
PlotFcst(ts,fcst)

# %%
fcst = ExpSmooth(ts=ts, hor=30, sl=0.2)
PlotFcst(ts,fcst)
# Out:
# c:\program files\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   warnings.warn('No frequency information was'

# %%
fcst = HoltWintersLin(ts=ts, hor=30, sl=0.3, ss=0.1)
PlotFcst(ts,fcst)
# Out:
# c:\program files\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   warnings.warn('No frequency information was'
# <ipython-input-29-1b878b8837bf>:29: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   fit = Holt(ts).fit(smoothing_level = sl,smoothing_slope = ss)

# %%
fcst = HoltWinters(ts=ts, hor=30, sp=7, trd='add', sea='none')
PlotFcst(ts,fcst)
# Out:
# c:\program files\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   warnings.warn('No frequency information was'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-a797d3f8bb79> in <module>
# ----> 1 fcst = HoltWinters(ts=ts, hor=30, sp=7, trd='add', sea='none')
#       2 PlotFcst(ts,fcst)
#
# <ipython-input-43-dbc8b319b302> in HoltWinters(ts, hor, sp, trd, sea)
#      32
#      33 def HoltWinters(ts, hor, sp, trd, sea):
# ---> 34     fit = ExponentialSmoothing(ts ,seasonal_periods=sp ,trend=trd, seasonal=sea,).fit()
#      35     fcst = fit.forecast(hor)
#      36     return fcst
#
# c:\program files\python38\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
# ...

# %%
ts.index
# Out:
# Index(['1/1/2017 0:15', '1/1/2017 0:30', '1/1/2017 0:45', '1/1/2017 1:00',
#        '1/1/2017 1:15', '1/1/2017 1:30', '1/1/2017 1:45', '1/1/2017 2:00',
#        '1/1/2017 2:15', '1/1/2017 2:30',
#        ...
#        '1/2/2017 11:15', '1/2/2017 11:30', '1/2/2017 11:45', '1/2/2017 12:00',
#        '1/2/2017 12:15', '1/2/2017 12:30', '1/2/2017 12:45', '1/2/2017 13:00',
#        '1/2/2017 13:15', '1/2/2017 13:30'],
#       dtype='object', name='date', length=150)
