# %% [markdown]
# # Trend detection

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
import trendet
from lstf.Visual.TrendCharts import PlotTrends

# %%
dft = trendet.identify_all_trends(stock='BBVA', country='Spain', from_date='01/01/2018', to_date='01/01/2019', window_size=5, identify='both')
#dft.to_csv('D:/LSTF/Data/trend_fcst/trends.csv')
dft = dft[['Close', 'Up Trend', 'Down Trend']]
dft.columns = ['value', 'up', 'down']
dft
# Out:
#             value   up down
# Date
# 2018-01-02  7.082    A  NaN
# 2018-01-03  7.094    A  NaN
# 2018-01-04  7.221    A  NaN
# 2018-01-05  7.253    A  NaN
# 2018-01-08  7.235    A  NaN
# ...           ...  ...  ...
# 2018-12-21  4.619  NaN  NaN
# 2018-12-24  4.558  NaN  NaN
# 2018-12-27  4.545  NaN  NaN
# 2018-12-28  4.641  NaN  NaN
# 2018-12-31  4.636  NaN  NaN
#
# [255 rows x 3 columns]

# %%
PlotTrends(dft)

# %%
#identify_df_trends(df, column, window_size=5, identify='both')
