# %% [markdown]
# # Detrending

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
from statsmodels.tsa.tsatools import detrend
from random import randrange

# %%
ts = np.array([i+randrange(10) for i in range(1,100)])

# %%
detr_ts = detrend(ts, order=1, axis=0)

# %%
plt.plot(ts);
plt.plot(detr_ts);

# %% [markdown]
# ### Differencing

# %%
ts_s = pd.Series(ts)
diff_ts = ts_s.diff(periods=1)
plt.plot(diff_ts);

# %% [markdown]
# ### Credits & Links

# %% [markdown]
# https://programtalk.com/python-examples/statsmodels.api.tsa.detrend/
