# %% [markdown]
# # TS Decomposition

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from random import randrange
from pandas import Series

# %% [markdown]
# ### Random data

# %% [markdown]
# #### Additive descomposition

# %%
ts = [i+randrange(10) for i in range(1,100)]
res = seasonal_decompose(ts, model='additive', period=1);
res.plot()
plt.show()

# %% [markdown]
# #### Multiplicative descomposition

# %%
ts = [i**2.0 for i in range(1,100)]
res = seasonal_decompose(ts, model='multiplicative', period=1)
res.plot()
plt.show()

# %% [markdown]
# ### Real data

# %%
ts = pd.read_csv('D:/data/csv/airline_passengers.csv', header=0, index_col=0)
plt.figure(figsize=(20,10))
plt.plot(ts)
plt.show()

# %%
ts = pd.read_csv('D:/data/csv/airline_passengers.csv', header=0, index_col=0)
res = seasonal_decompose(ts, model='additive', period=1)
res.plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(res.trend);

# %% [markdown]
# ## Credits & Links

# %% [markdown]
# https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/
