# %% [markdown]
# # Fast Fourier Transform

# %%
from utilities.std_imports import *
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20, 10)
import scipy.signal
import scipy.special
import scipy.stats as st
from scipy import pi
from scipy.fftpack import fft

# %%
df =pd.read_csv(ts_path + 'shampoo.csv')
df.plot();

# %%
freq = np.fft.fftfreq(len(df))

# %%
psd = np.abs(np.fft.fft(df['Sales'].values))**2 / len(df)

plt.plot(freq[freq>=0], psd[freq>=0])
plt.xlabel('freq (Hz)')
plt.ylabel('PSD')
plt.margins(0.02)

# %%
sample_rate = 7
n = df.shape[0]
n_sr = n/sample_rate
n_sr
n = (n_sr - 0) * sample_rate
n
time = np.linspace(0, int(n_sr), int(n))

# %%
frequency = np.linspace (0.0, 36, int (N/2))

freq_data = np.fft.fft(df['Sales'].values)
y = 2/N * np.abs (freq_data [0:np.int (N/2)])

# %%
plt.plot(frequency, y)
plt.title('Frequency domain Signal')
plt.xlabel('Frequency in Hz')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
